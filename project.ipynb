# %% [markdown]
# # Basic Python Practices
#
# #### Exercise 00. Variable Declaration
#
# Define the following variables with values of your choice:
#
# - A variable that stores your name (text).
# - A variable that stores your age (integer).
# - A variable that indicates if you like programming (true or false).
# - A variable that stores your average grade (decimal number).

# %%
# Declare your variables here.
name = "Anee"
age = 85
is_student = True
average_grade = 98.9
#Example
greeting = "Hello world"

# %% [markdown]
# - Create a list with your five favorite numbers and print it.

# %%
# Favorite numbers list
favourite_numbers = [10,20,30,40,50]
print (favourite_numbers)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# - Create a dictionary that stores a student's information and print it:
#
#         - Name
#         - Age
#         - Final grade

# %%
#TODO
student ={
    "name": name,
    "age":age,
    "average_grade": average_grade
}
print(student)
# Out:
# {'name': 'Anee', 'age': 85, 'average_grade': 98.9}

# %% [markdown]
# #### Exercise 01. Basic data analysis with native Python structures.
# Create a list with the grades of 5 students: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calculate the average of the grades.

# %%
# TODO using NUMPY - mean() for getting average
import numpy as np
list_of_grades = [8.5,9.2,7.8,8.9,10]
grades_np_array = np.array(list_of_grades)
average_grade = np.mean(grades_np_array)
print(average_grade)
# Out:
# 8.879999999999999

# %%
#Alternative solution USING pandas -series Cell#5
import pandas as pd
grades_list_pd_series = pd.Series([8.5,9.2,7.8,8.9,10])
average_grade = grades_list_pd_series.mean()
print(average_grade)
# Out:
# 8.879999999999999

# %% [markdown]
# - Find the highest and lowest grade.

# %%
# TODO
print("The highest grade is:", max(list_of_grades))
print("The lowest grade is:", min(list_of_grades))
# Out:
# The highest grade is: 10
# The lowest grade is: 7.8

# %%
#Alternative solution using numpy and pandas
#using numpy
highest_grade_np = np.max(grades_np_array)
lowest_grade_np = np.min(grades_np_array)
print("Using Numpy - Highest grade:", highest_grade_np)
print("Using Numpy - Lowest grade:", lowest_grade_np)

#using pandas grades_list taken from cell#5
highest_grade_pd = grades_list_pd_series.max() 
lowest_grade_pd = grades_list_pd_series.min()
# Out:
# Using Numpy - Highest grade: 10.0
# Using Numpy - Lowest grade: 7.8

# %% [markdown]
# # Real estate data cleaning with Pandas for efficient analysis
#
# This is a real dataset that was downloaded using web scraping techniques. The data contains records from **Fotocasa**, one of the most popular real estate websites in Spain. Please do not perform web scraping unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and no economic benefit was obtained from it.
#
# It contains thousands of real house listings published on the website www.fotocasa.com. Your goal is to extract as much information as possible with the data science knowledge you have acquired so far.
#
# Let's get started!
#
# - First, let's read and explore the dataset.

# %%
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds # mostramos todo
#First clean the data in the dataframe, so it should not have any empty or null values or NAN or zeros in columns that dont support these values. Like 'prices and 'surface'
# the below code is commented as this 'dropna()' would remove the rows with null values, but we want to keep the dataset as is for analysis.
# ds = ds.dropna(subset=['price', 'surface'])
# ds = ds[ds['price'] > 0]
# ds = ds[ds['surface'] > 0]
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Display the first rows of the CSV file.

# %%
# TODO iloc method to get the index=0 location--> index-> points to the row..
print("The first row of the file given is:\n", ds.iloc[0])
# Out:
# The first row of the file given is:
#  Unnamed: 0                                                          1
# id_realEstates                                              153771986
# isNew                                                           False
# realEstate_name                               ferrari 57 inmobiliaria
# phone_realEstate                                          912177526.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         2.0
# surface                                                         103.0
# price                                                          195000
# date                                     2019-12-28T18:27:15.9975027Z
# description         Ponemos a la venta piso de 3 dormitorios con t...
# address             Calle Presidente Felipe Gonzalez, Arganda del Rey
# ...

# %% [markdown]
# Perfect, this was a small practice. Now let's begin with the real exercises!

# %% [markdown]
# #### Exercise 01. What is the most expensive house in the entire dataset? (★☆☆)
#
# Print the address and price of the selected house. For example:
#
# `The house located at Calle del Prado, Nº20 is the most expensive, and its price is 5000000 USD.`

# %%
# TODO
# expensive_house = ds.loc[ds["price"].idxmax()]

cleaned_ds = ds[(ds["price"]>0) & (ds["surface"]>0)] 
expensive_house = cleaned_ds.loc[cleaned_ds["price"].idxmax()]

print(f"The house located at {expensive_house["address"]} is the most expensive, and its price is {expensive_house["price"]}")
# Out:
# The house located at  Madrid Capital is the most expensive, and its price is 8000000

# %% [markdown]
# #### Exercise 02. What is the cheapest house in the dataset? (★☆☆)
#
# This exercise is similar to the previous one, except now we are looking for the house with the lowest price. Remember to print the address and price of the selected house. For example:
#
# `The house located at Calle Alcalá, Nº58 is the cheapest, and its price is 12000 USD.`

# %%
# TODO

least_expensive = cleaned_ds.loc[cleaned_ds["price"].idxmin()]
print(f"The house located at {least_expensive["address"]} is the cheapest, and its price is {least_expensive["price"]}")
# Out:
# The house located at Berlin, Coslada is the cheapest, and its price is 600

# %% [markdown]
# #### Exercise 03. What is the largest and smallest house in the dataset? (★☆☆)
#
# Print the address and area of the selected houses. For example:
#
# `The largest house is located at Calle Gran Vía, Nº38, and its area is 5000 square meters.`
#
# `The smallest house is located at Calle Mayor, Nº12, and its area is 200 square meters.`
#
# This exercise is similar to the previous one, but we are looking for the largest and smallest houses based on their area.

# %%
# TODO

largest_house = cleaned_ds.iloc[cleaned_ds["surface"].idxmax()]
print("The largest house is located at"+ largest_house["address"]+ "and its area is "+ str(largest_house["surface"]))

smallest_house = cleaned_ds.loc[cleaned_ds["surface"].idxmin()]
print("The smallest house is located at"+ smallest_house["address"]+ "and its area is "+ str(smallest_house["surface"]))
# Out:
# The largest house is located atAvenida Avda del Ejército, Arganda del Reyand its area is 159.0
# The smallest house is located atCalle Amparo,  Madrid Capitaland its area is 15.0

# %% [markdown]
# #### Exercise 04. How many unique populations are in the dataset? (★☆☆)
#
# Count the number of unique populations in the 'level5' column and print the names of the populations separated by commas. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

# cleaned_address = ds["level5"].where(ds["level5"].notna())
# print(f"cleaned after not considering the NAN addresses: {cleaned_address}")
# print(ds["level5"])
set_of_unique_addresses = set(ds["level5"])
temp_series = pd.Series(list(set_of_unique_addresses))
print(f"\n\nUnique addresses in the attached file is : \n{temp_series.sort_values()}")
# Out:
# Unique addresses in the attached file is :
# 163           Madrid Capital
# 89                   Ajalvir
# 30         Alcalá de Henares
# 126               Alcobendas
# 158                 Alcorcón
#                ...
# 111          Villar del Olmo
# 32     Villarejo de Salvanés
# 138     Villaviciosa de Odón
# 17     Villavieja del Lozoya
# 24                 Zarzalejo
# Length: 168, dtype: object

# %% [markdown]
# #### Exercise 05. Does the dataset contain null values (NAs)? (★☆☆)
#
# Print a boolean (`True` or `False`) to check if there are null values, followed by the columns that contain NAs.

# %%
# TODO
dataset_has_Nans = ds.isna().any().any()
print (f"The dataset has Nans: \n{dataset_has_Nans}")
# Out:
# The dataset has Nans:
# True

# %% [markdown]
# #### Exercise 06. Remove the null values (NAs) from the dataset, if applicable (★★☆)
#
# After removing the null values, compare the size of the DataFrame before and after the removal.

# %%
# TODO
ds_before_removing_nans = ds
ds_after_removing_nans = ds.dropna()
print(f"Number of rows before removing Nans: {len(ds_before_removing_nans)}")
print(f"Number of rows after removing Nans: {len(ds_after_removing_nans)}")  
print (ds_after_removing_nans)
# Out:
# Number of rows before removing Nans: 15335
# Number of rows after removing Nans: 0
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Exercise 07. What is the average price in the population of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the value obtained from the 'level5' column.

# %%
# TODO
temp = ds["price"].where(ds["level5"]=="Arroyomolinos (Madrid)").mean()
avg_price = temp
print(f"The average price of houses in the Arroyomolinos is: {avg_price}")

temp1 =  np.mean(ds["price"].where(ds["level5"]=="Arroyomolinos (Madrid)").dropna()) #-->alternative way
print(temp1)
# Out:
# The average price of houses in the Arroyomolinos is: 294541.59854014596
# 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write a brief analysis of the plot in the Markdown cell.

# %%
import matplotlib.pyplot as plt

# Plot the histogram of prices
print("Plotting the histogram of prices...")
plt.hist(ds["price"].dropna(), bins=10, color='blue', alpha=0.5)
plt.title('Histogram of House Prices')
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.grid(True)
plt.show()
# Out:
# Plotting the histogram of prices...
